# %% [markdown]
# # NODES

# %% [raw]
# application=['SK_ID_CURR','CODE_GENDER','CNT_CHILDREN','NAME_INCOME_TYPE','NAME_EDUCATION_TYPE','NAME_FAMILY_TYPE','NAME_HOUSING_TYPE','OCCUPATION_TYPE']

# %%
import pandas as pd
import sys
import numpy as np
import os

# %%
# Create the folder if it already doesn't exist# Create  
if not os.path.exists('graph_csv_1000k'):
    os.makedirs('graph_csv_1000k')

# %% [markdown]
# # Application.csv

# %%
data=pd.read_csv("data/application_train.csv",index_col=0)

# %%
data=data.iloc[0:1000]
# list(data.columns)

# %%
attr_list =['SK_ID_CURR','CODE_GENDER','CNT_CHILDREN','NAME_INCOME_TYPE','NAME_EDUCATION_TYPE','NAME_FAMILY_STATUS','NAME_HOUSING_TYPE','OCCUPATION_TYPE']
attr_set = set(attr_list)

# %%
df_export = data

# %%
# df.to_csv('graph_csv/application.csv',index_label="applicationId:SK_ID_CURR(Applications)",float_format="%.10g")
df_export.to_csv('graph_csv_1000k/application.csv',index=True,index_label="SK_ID_CURR:ID(Application)")

# %%
df_export.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 100002 to 101156
# Columns: 121 entries, TARGET to AMT_REQ_CREDIT_BUREAU_YEAR
# dtypes: float64(65), int64(40), object(16)
# memory usage: 953.1+ KB

# %% [markdown]
# # previous.application.csv

# %%
prev=pd.read_csv('data/previous_application.csv',index_col=0)
# Out:
# /usr/local/lib/python3.6/site-packages/numpy/lib/arraysetops.py:472: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
currId=list(df_export.index)
df_prev=prev[prev['SK_ID_CURR'].isin(currId)] 
df_prev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4769 entries, 1891648 to 2276384
# Data columns (total 36 columns):
# SK_ID_CURR                     4769 non-null int64
# NAME_CONTRACT_TYPE             4769 non-null object
# AMT_ANNUITY                    3692 non-null float64
# AMT_APPLICATION                4769 non-null float64
# AMT_CREDIT                     4769 non-null float64
# AMT_DOWN_PAYMENT               2235 non-null float64
# AMT_GOODS_PRICE                3681 non-null float64
# WEEKDAY_APPR_PROCESS_START     4769 non-null object
# HOUR_APPR_PROCESS_START        4769 non-null int64
# FLAG_LAST_APPL_PER_CONTRACT    4769 non-null object
# NFLAG_LAST_APPL_IN_DAY         4769 non-null int64
# RATE_DOWN_PAYMENT              2235 non-null float64
# RATE_INTEREST_PRIMARY          12 non-null float64
# RATE_INTEREST_PRIVILEGED       12 non-null float64
# NAME_CASH_LOAN_PURPOSE         4769 non-null object
# NAME_CONTRACT_STATUS           4769 non-null object
# ...

# %%
currId=set(currId)
b=set(df_prev['SK_ID_CURR'])
b-currId
# Out:
# set()

# %%
df_prev.to_csv('graph_csv_1000k/previous_application.csv',index=True,index_label="SK_ID_PREV:ID(Previous_Application)")
df_prev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4769 entries, 1891648 to 2276384
# Data columns (total 36 columns):
# SK_ID_CURR                     4769 non-null int64
# NAME_CONTRACT_TYPE             4769 non-null object
# AMT_ANNUITY                    3692 non-null float64
# AMT_APPLICATION                4769 non-null float64
# AMT_CREDIT                     4769 non-null float64
# AMT_DOWN_PAYMENT               2235 non-null float64
# AMT_GOODS_PRICE                3681 non-null float64
# WEEKDAY_APPR_PROCESS_START     4769 non-null object
# HOUR_APPR_PROCESS_START        4769 non-null int64
# FLAG_LAST_APPL_PER_CONTRACT    4769 non-null object
# NFLAG_LAST_APPL_IN_DAY         4769 non-null int64
# RATE_DOWN_PAYMENT              2235 non-null float64
# RATE_INTEREST_PRIMARY          12 non-null float64
# RATE_INTEREST_PRIVILEGED       12 non-null float64
# NAME_CASH_LOAN_PURPOSE         4769 non-null object
# NAME_CONTRACT_STATUS           4769 non-null object
# ...

# %%
df_prev.index=='2582071'
# Out:
# False

# %% [markdown]
# # Bureau.csv

# %%
bureaudata=pd.read_csv("data/bureau.csv",index_col=1)

# %%
currId=list(df_export.index)
currId
# Out:
# [100002,
#  100003,
#  100004,
#  100006,
#  100007,
#  100008,
#  100009,
#  100010,
#  100011,
#  100012,
#  100014,
#  100015,
#  100016,
#  100017,
#  100018,
#  100019,
#  100020,
#  100021,
#  100022,
#  100023,
#  100024,
#  100025,
#  100026,
#  100027,
#  100029,
#  100030,
#  100031,
#  100032,
#  100033,
#  100034,
#  100035,
#  100036,
#  100037,
#  100039,
#  100040,
#  100041,
#  100043,
#  100044,
#  100045,
#  100046,
#  100047,
#  100048,
#  100049,
#  100050,
#  100051,
#  100052,
#  100053,
#  100054,
#  100055,
#  100056,
#  100058,
#  100059,
#  100060,
#  100061,
#  100062,
#  100063,
#  100064,
#  100068,
#  100069,
#  100070,
#  100071,
#  100072,
#  100073,
#  100075,
#  100076,
#  100077,
#  100078,
#  100079,
#  100080,
#  100081,
#  100082,
#  100083,
#  100084,
#  100085,
#  100086,
#  100087,
#  100088,
#  100089,
#  100093,
#  100094,
#  100095,
#  100096,
#  100097,
#  100098,
#  100099,
#  100100,
#  100101,
#  100102,
#  100103,
#  100104,
# ...

# %%
df_bureau=bureaudata[bureaudata['SK_ID_CURR'].isin(currId)]
sorted(df_id_output['SK_ID_CURR'])
# Out:
# [100006,
#  100006,
#  100006,
#  100006,
#  100006,
#  100006,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100011,
#  100021,
#  100021,
#  100021,
#  100021,
#  100021,
#  100021,
#  100021,
#  100021,
#  100021,
#  100021,
# ...

# %%
df_id_output.head()
# Out:
#               SK_ID_CURR CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# SK_ID_BUREAU
# 5715559           101060        Closed      currency 1        -1087
# 5715560           101060        Active      currency 1         -709
# 5715561           101060        Active      currency 1         -886
# 5715564           101060        Closed      currency 1        -2632
# 5721463           100802        Active      currency 1         -525
#
#               CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# SK_ID_BUREAU
# 5715559                        0               -874.0             -902.0
# 5715560                        0                783.0                NaN
# 5715561                        0                479.0                NaN
# 5715564                        0              -2478.0            -2541.0
# 5721463                        0                928.0                NaN
#
#               AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# ...

# %%
currId=set(currId)
output=set(df_bureau['SK_ID_CURR'])

# %%
output - currId
# Out:
# set()

# %%
# currId=list(df_export['SK_ID_CURR'])
# currId
# df_id_output=data[data['SK_ID_CURR'].isin(currId)]

# %%
df_bureau.to_csv("graph_csv_1000k/bureau.csv",index=True,index_label="SK_ID_BUREAU:ID(Bureau)")

# %%
df_bureau.head()
# Out:
#               SK_ID_CURR CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# SK_ID_BUREAU
# 5715559           101060        Closed      currency 1        -1087
# 5715560           101060        Active      currency 1         -709
# 5715561           101060        Active      currency 1         -886
# 5715564           101060        Closed      currency 1        -2632
# 5721463           100802        Active      currency 1         -525
#
#               CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# SK_ID_BUREAU
# 5715559                        0               -874.0             -902.0
# 5715560                        0                783.0                NaN
# 5715561                        0                479.0                NaN
# 5715564                        0              -2478.0            -2541.0
# 5721463                        0                928.0                NaN
#
#               AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# ...

# %% [markdown]
# # Bureau_balance.csv

# %%
balance=pd.read_csv("data/bureau_balance.csv")

# %%
currId=list(df_bureau.index)

# %%
currId
# Out:
# [5715559,
#  5715560,
#  5715561,
#  5715564,
#  5721463,
#  5721932,
#  5721933,
#  5721934,
#  5721936,
#  5721937,
#  5721938,
#  5721939,
#  5721940,
#  5721941,
#  5721943,
#  5721944,
#  5721945,
#  5721946,
#  5721947,
#  5721948,
#  5721949,
#  5721950,
#  5721952,
#  5722930,
#  5723577,
#  5723578,
#  5723579,
#  5723580,
#  5723581,
#  5723582,
#  5723583,
#  5723952,
#  5726282,
#  5726283,
#  5726284,
#  5726285,
#  5726286,
#  5726287,
#  5726288,
#  6023751,
#  6023752,
#  6023753,
#  6023754,
#  6023755,
#  6023756,
#  6024123,
#  6024124,
#  6024126,
#  6024127,
#  6024128,
#  6024129,
#  6024130,
#  6024131,
#  5190197,
#  5190198,
#  5190199,
#  5190200,
#  5192775,
#  5192776,
#  5192777,
#  5192778,
#  5192779,
#  5193383,
#  5193384,
#  5193385,
#  5193810,
#  5197113,
#  5201794,
#  5201795,
#  5202357,
#  5202358,
#  5202359,
#  5202361,
#  5202362,
#  5203458,
#  5203459,
#  5203460,
#  5203462,
#  5203463,
#  5203464,
#  5203465,
#  5800488,
#  5800489,
# ...

# %%
df_bureau_bal=balance[balance['SK_ID_BUREAU'].isin(currId)]
df_bureau_bal
# Out:
#           SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 81446          5228926             -47      C
# 81447          5228926             -48      C
# 81448          5228926             -49      C
# 81449          5228926             -50      C
# 81450          5228926             -51      C
# 81451          5228926             -52      0
# 81452          5228926             -53      X
# 81453          5228928               0      C
# 81454          5228928              -1      C
# 81455          5228928              -2      C
# 81456          5228928              -3      C
# 81457          5228928              -4      C
# 81458          5228928              -5      C
# 81459          5228928              -6      C
# 81460          5228928              -7      C
# 81461          5228928              -8      C
# 81462          5228928              -9      C
# 81463          5228928             -10      C
# 81464          5228928             -11      C
# ...

# %%
set(df_bureau_bal['SK_ID_BUREAU'])-set(currId)
# Out:
# set()

# %%
df_bureau_bal.to_csv('graph_csv_1000k/bureau_balance.csv',index=True,index_label="SK_ID_BUREAU:ID(Bureau_Balance)")

# %%
df_bureau_bal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43079 entries, 81446 to 27131678
# Data columns (total 3 columns):
# SK_ID_BUREAU      43079 non-null int64
# MONTHS_BALANCE    43079 non-null int64
# STATUS            43079 non-null object
# dtypes: int64(2), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# # credit_card_balance.csv

# %%
credit=pd.read_csv("data/credit_card_balance.csv")

# %%
currId=list(df_prev['SK_ID_CURR'])
prevId=list(prev_data.index)

# %%
df_credit=credit[credit['SK_ID_CURR'].isin(currId)]

# %%
df_credit=df_credit[df_credit['SK_ID_PREV'].isin(prevId)]
df_credit
# Out:
#          SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  AMT_BALANCE  \
# 124         2306532      100796              -4        0.000
# 825         1375058      100662              -5        0.000
# 976         1727561      100218              -4   748180.935
# 1149        2241207      100722              -1        0.000
# 1363        1944493      101111              -4        0.000
# 1425        1060558      100048              -2    27302.400
# 2487        1880847      100135              -5        0.000
# 3266        2153525      100394              -4        0.000
# 3499        1787234      100059              -4        0.000
# 3728        1683599      100942              -2   417874.545
# 3954        1822938      100756              -5        0.000
# 5252        1083054      100284             -19        0.000
# 5257        2580197      100681             -20        0.000
# 6423        1298506      100526              -3        0.000
# ...

# %%
df_credit.to_csv('graph_csv_1000k/credit_card_balance.csv',index=True,index_label="SK_ID_CURR:ID(CreditCardBal)")

# %%
a=set(df_id_output['SK_ID_PREV'])
c=set(prevId)
a-c
# Out:
# set()

# %% [markdown]
# # pos_cash_balance.csv

# %%
pos=pd.read_csv('data/pos_cash_balance.csv')

# %%
currId=list(df_prev['SK_ID_CURR'])
prevId=list(prev_data.index)

# %%
df_pos_cash=pos[pos['SK_ID_PREV'].isin(prevId)]
df_pos_cash=df_pos_cash[df_pos_cash['SK_ID_CURR'].isin(currId)]
df_pos_cash.head()
# Out:
#       SK_ID_PREV  SK_ID_CURR  MONTHS_BALANCE  CNT_INSTALMENT  \
# 183      2547775      100676             -41            24.0
# 854      2687776      100457             -16            24.0
# 1117     1653280      100442             -37            24.0
# 1155     1474042      101037             -38            48.0
# 1828     1364429      100525             -24            12.0
#
#       CNT_INSTALMENT_FUTURE NAME_CONTRACT_STATUS  SK_DPD  SK_DPD_DEF
# 183                    12.0               Active       0           0
# 854                    23.0               Active       0           0
# 1117                   14.0               Active       0           0
# 1155                   40.0               Active       0           0
# 1828                    0.0            Completed       0           0

# %%
df_pos_cash.to_csv('graph_csv_1000k/pos_cash_balance.csv',index=True,index_label="SK_ID_CURR:ID(POS)")

# %%
df_pos_cash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27971 entries, 183 to 10001201
# Data columns (total 8 columns):
# SK_ID_PREV               27971 non-null int64
# SK_ID_CURR               27971 non-null int64
# MONTHS_BALANCE           27971 non-null int64
# CNT_INSTALMENT           27878 non-null float64
# CNT_INSTALMENT_FUTURE    27878 non-null float64
# NAME_CONTRACT_STATUS     27971 non-null object
# SK_DPD                   27971 non-null int64
# SK_DPD_DEF               27971 non-null int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 1.9+ MB

# %% [markdown]
# # installments_payments.csv

# %%
inst=pd.read_csv('data/installments_payments.csv')

# %%
df_inst=inst[inst['SK_ID_CURR'].isin(currId)]
df_inst=df_inst[df_inst['SK_ID_PREV'].isin(prevId)]

# %%
df_inst.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36288 entries, 14 to 3799665
# Data columns (total 8 columns):
# SK_ID_PREV                36288 non-null int64
# SK_ID_CURR                36288 non-null int64
# NUM_INSTALMENT_VERSION    36288 non-null float64
# NUM_INSTALMENT_NUMBER     36288 non-null int64
# DAYS_INSTALMENT           36288 non-null float64
# DAYS_ENTRY_PAYMENT        36282 non-null float64
# AMT_INSTALMENT            36288 non-null float64
# AMT_PAYMENT               36282 non-null float64
# dtypes: float64(5), int64(3)
# memory usage: 2.5 MB

# %%
df_inst.to_csv('graph_csv_1000k/installments_payments.csv',index=True,index_label="SK_ID_CURR:ID(Installments_Payment)")

# %% [markdown]
# # RELATIONSHIPS

# %% [raw]
# 1. application-->previous_application
# 2. application-->bureau
# 3. bureau-->bureau_balance
# 4. application-->credit_card_balance
# 5. previous_application-->credit_card_balance
# 6. previous_application-->installments_payment
# 7. application-->installments_payment
# 8. application-->pos_cash_balance
# 9. previous_balance-->pos_cash_balance

# %%
# 1. application-->previous_application
one=pd.read_csv('graph_csv_1000k/previous_application.csv')

# %%
oned=one[['SK_ID_CURR','SK_ID_PREV:ID(Previous_Application)']]
oned
# Out:
#       SK_ID_CURR  SK_ID_PREV:ID(Previous_Application)
# 0         100373                              1891648
# 1         100077                              2670402
# 2         101011                              1514511
# 3         100425                              1539382
# 4         100151                              1614986
# 5         100667                              1111156
# 6         100916                              1801757
# 7         100307                              2685304
# 8         100201                              2227969
# 9         100279                              2034342
# 10        100587                              1465837
# 11        100527                              1921372
# 12        100980                              1248695
# 13        100124                              1986247
# 14        101067                              1356683
# 15        100891                              1824766
# ...

# %%
oned.to_csv('graph_csv_1000k/curr_to_prev.csv',index=False,
            header=[":START_ID(Application)",":END_ID(Previous_Application)"])

# %%
# 2. application-->bureau
one=pd.read_csv('graph_csv_1000k/bureau.csv')
oned=one[['SK_ID_CURR','SK_ID_BUREAU:ID(Bureau)']]

oned.to_csv('graph_csv_1000k/curr_to_bureau.csv',index=False,
            header=[":START_ID(Application)",":END_ID(Bureau)"])

# %%
# 3. bureau-->bureau_balance
one=pd.read_csv('graph_csv_1000k/bureau_balance.csv')
one.head()
# Out:
#    SK_ID_BUREAU:ID(Bureau_Balance)  SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 0                            81446       5228926             -47      C
# 1                            81447       5228926             -48      C
# 2                            81448       5228926             -49      C
# 3                            81449       5228926             -50      C
# 4                            81450       5228926             -51      C

# %%
oned=one[['SK_ID_BUREAU','SK_ID_BUREAU:ID(Bureau_Balance)']]

oned.to_csv('graph_csv_1000k/bureau_to_bureauBal.csv',index=False,
            header=[":START_ID(Bureau)",":END_ID(Bureau_Balance)"])

# %%
# 4. application-->credit_card_balance
# one=pd.read_csv('graph_csv_1000k/credit_card_balance.csv')
# one

# oned=one[['SK_ID_CURR','SK_ID_CURR:ID(CreditCardBal)']]

# oned.to_csv('graph_csv_1000k/curr_to_creditCardBal.csv',index=False,
#             header=[":START_ID(Application)",":END_ID(CreditCardBal)"])
# oned

# %%
# 5. previous_application-->credit_card_balance
one=pd.read_csv('graph_csv_1000k/credit_card_balance.csv')


oned=one[['SK_ID_PREV','SK_ID_CURR:ID(CreditCardBal)']]
oned
oned.to_csv('graph_csv_1000k/prev_to_creditCardBal.csv',index=False,
             header=[":START_ID(Previous_Application)",":END_ID(CreditCardBal)"])

# %%
# 6. previous_application-->installments_payment

one=pd.read_csv('graph_csv_1000k/installments_payments.csv')

one
oned=one[['SK_ID_PREV','SK_ID_CURR:ID(Installments_Payment)']]

oned.to_csv('graph_csv_1000k/prev_to_installment.csv',index=False,
            header=[":START_ID(Previous_Application)",":END_ID(Installments_Payment)"])

# %%
# 7. application-->installments_payment

# one=pd.read_csv('graph_csv_1000k/installments_payments.csv')

# one
# # one.head()
# oned=one[['SK_ID_CURR','SK_ID_CURR:ID(Installments_Payment)']]

# oned.to_csv('graph_csv_1000k/curr_to_installment.csv',index=False,
#             header=[":START_ID(Application)",":END_ID(Installments_Payment)"])

# %%
# 8. application-->pos_cash_balance
# one=pd.read_csv('graph_csv_1000k/pos_cash_balance.csv')

# oned=one[['SK_ID_CURR','SK_ID_CURR:ID(POS)']]

# oned.to_csv('graph_csv_1000k/curr_to_pos.csv',index=False,
#             header=[":START_ID(Application)",":END_ID(POS)"])

# %%
# 9. previous_balance-->pos_cash_balance
one=pd.read_csv('graph_csv_1000k/pos_cash_balance.csv')
one.head()
oned=one[['SK_ID_PREV','SK_ID_CURR:ID(POS)']]

oned.to_csv('graph_csv_1000k/prev_to_pos.csv',index=False,
            header=[":START_ID(Previous_Application)",":END_ID(POS)"])

# %% [raw]
# bin\neo4j-admin.bat
# import --nodes:Application import/application.csv
# --nodes:Bureau import/bureau.csv
# --nodes:Bureau_Balance  import/bureau_balance.csv
# --nodes:CreditCardBal  import/cerdit_card_balance.csv
# --nodes:Installments_Payment  import/installments_payments.csv
# --nodes:POS  import/pos_cash_balance.csv
# --nodes:Previous_Application  import/previous_application.csv
# --relationships:HAS_PREVIOUS import/curr_to_prev.csv
# --relationships:HAS_BUREAU  import/curr_to_bureau.csv
# --relationships:CURR_CREDIT_BAL  import/curr_creditCardBal.csv
# --relationships:PREV_CREDIT_BAL  import/prev_creditCardBal.csv
# --relationships:HAS_CURR_INSTALLMENTS  import/curr_to_installment.csv
# --relationships:HAS_PREV_INSTALLMENTS  import/prev_to_installment.csv
# --relationships:HAS_CURR_POS import/curr_to_pos.csv
# --relationships:HAS_PREV_POS import/prev_to_pos.csv
# --relationships:HAS_BUREAU_BAL import/bureau_to_bureauBal.csv

# %%
bin\neo4j-admin.bat import --nodes:CreditCardBal import/credit_card_balance.csv --nodes:Application import/application.csv --nodes:Bureau  import/bureau.csv --nodes:Bureau_Balance  import/bureau_balance.csv  --nodes:Installments_Payment  import/installments_payments.csv --nodes:POS  import/pos_cash_balance.csv --nodes:Previous_Application  import/previous_application.csv --relationships:HAS_PREVIOUS import/curr_to_prev.csv  --relationships:HAS_BUREAU  import/curr_to_bureau.csv  --relationships:CURR_CREDIT_BAL  import/curr_to_creditCardBal.csv   --relationships:HAS_CURR_INSTALLMENTS  import/curr_to_installment.csv --relationships:HAS_CURR_POS import/curr_to_pos.csv  --relationships:HAS_BUREAU_BAL import/bureau_to_bureauBal.csv --relationships:PREV_CREDIT_BAL  import/prev_to_creditCardBal.csv --relationships:HAS_PREV_INSTALLMENTS  import/prev_to_installment.csv --relationships:HAS_PREV_POS import/prev_to_pos.csv

# %% [raw]
#     bin\neo4j-admin.bat import --nodes:CreditCardBal import/credit_card_balance.csv --nodes:Application import/application.csv --nodes:Bureau  import/bureau.csv --nodes:Bureau_Balance  import/bureau_balance.csv  --nodes:Installments_Payment  import/installments_payments.csv --nodes:POS  import/pos_cash_balance.csv --nodes:Previous_Application  import/previous_application.csv --relationships:HAS_PREVIOUS import/curr_to_prev.csv  --relationships:HAS_BUREAU  import/curr_to_bureau.csv  --relationships:CURR_CREDIT_BAL  import/curr_to_creditCardBal.csv   --relationships:HAS_CURR_INSTALLMENTS  import/curr_to_installment.csv --relationships:HAS_CURR_POS import/curr_to_pos.csv  --relationships:HAS_BUREAU_BAL import/bureau_to_bureauBal.csv

# %% [raw]
# bin\neo4j-admin.bat import
# --nodes:Terms import/terms.csv
# --nodes:Work  import/workdetails.csv
# --nodes:Application  import/application.csv
# --nodes:Loansts  import/loanstatus.csv
# --nodes:Purpose  import/purpose.csv
# --nodes:Apptype  import/apptype.csv
# --nodes:Address  import/address.csv
# --nodes:Loan  import/loan.csv
# --relationships:WORKS  import/appid_to_workdetails.csv
# --relationships:LIVES  import/appid_to_address.csv
# --relationships:takes_loan  import/appid_to_loan.csv
# --relationships:loan_term import/appid_to_terms.csv
# --relationships:loan_status  import/appid_to_loanstatus.csv
# --relationships:application_purpose  import/appid_to_purpose.csv
# --relationships:application_type import/appid_to_apptype.csv

# %%
creditcard=pd.read_csv('graph_csv/credit_card_balance.csv')
creditcard
# Out:
#      SK_ID_CURR:ID(CreditCardBal) NAME_CONTRACT_STATUS  SK_ID_PREV  SK_ID_CURR
# 0                             124               Active     2306532      100796
# 1                             825               Active     1375058      100662
# 2                             976               Active     1727561      100218
# 3                            1149               Active     2241207      100722
# 4                            1363            Completed     1944493      101111
# 5                            1425               Active     1060558      100048
# 6                            2487               Active     1880847      100135
# 7                            3266            Completed     2153525      100394
# 8                            3484            Completed     2080876      100436
# 9                            3499            Completed     1787234      100059
# 10                           3728               Active     1683599      100942
# ...

# %% [markdown]
# # Instruction for upload:
#
# 1. Delete graph.db
# 2. Place files to the import folder
# 3. Run the script
#     For windows: use terminal from the neo4j desktop
#     For Linux: start a terminal from inside the import folder of neo4j from etc/neo4j
# 1. Expected '--nodes' to have at least 1 valid item, but had 0 []
#
#     For this error, ensure that the files are at the correct folder
