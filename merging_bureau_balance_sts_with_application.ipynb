# %%
import pandas as pd
import numpy as np

# %%
df_bureau_bal_max = pd.read_csv('result_data/bureau_max_status_count.csv')

# %%
df_bureau = pd.read_csv('data/bureau.csv')

# %%
df_bureau
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0            215354       5714462        Closed      currency 1         -497
# 1            215354       5714463        Active      currency 1         -208
# 2            215354       5714464        Active      currency 1         -203
# 3            215354       5714465        Active      currency 1         -203
# 4            215354       5714466        Active      currency 1         -629
# 5            215354       5714467        Active      currency 1         -273
# 6            215354       5714468        Active      currency 1          -43
# 7            162297       5714469        Closed      currency 1        -1896
# 8            162297       5714470        Closed      currency 1        -1146
# 9            162297       5714471        Active      currency 1        -1146
# 10           162297       5714472        Active      currency 1        -1146
# ...

# %%
df_bureau.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1716428 entries, 0 to 1716427
# Data columns (total 17 columns):
# SK_ID_CURR                int64
# SK_ID_BUREAU              int64
# CREDIT_ACTIVE             object
# CREDIT_CURRENCY           object
# DAYS_CREDIT               int64
# CREDIT_DAY_OVERDUE        int64
# DAYS_CREDIT_ENDDATE       float64
# DAYS_ENDDATE_FACT         float64
# AMT_CREDIT_MAX_OVERDUE    float64
# CNT_CREDIT_PROLONG        int64
# AMT_CREDIT_SUM            float64
# AMT_CREDIT_SUM_DEBT       float64
# AMT_CREDIT_SUM_LIMIT      float64
# AMT_CREDIT_SUM_OVERDUE    float64
# CREDIT_TYPE               object
# DAYS_CREDIT_UPDATE        int64
# AMT_ANNUITY               float64
# dtypes: float64(8), int64(6), object(3)
# memory usage: 222.6+ MB

# %%
df_bureau_bal_max.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817395 entries, 0 to 817394
# Data columns (total 2 columns):
# SK_ID_BUREAU    817395 non-null int64
# STATUS          817395 non-null object
# dtypes: int64(1), object(1)
# memory usage: 12.5+ MB

# %%
df_bureau_bal_max.head()
# Out:
#    SK_ID_BUREAU STATUS
# 0       5642348      X
# 1       6031052      C
# 2       6031110      C
# 3       6547223      C
# 4       6766823      X

# %%
df_aggregate = pd.merge(df_bureau,df_bureau_bal_max,on='SK_ID_BUREAU')

# %%
df_aggregate.head(10)
# Out:
#    SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 0      380361       5715448        Active      currency 1         -820
# 1      380361       5715449        Active      currency 1         -357
# 2      380361       5715451        Closed      currency 1         -917
# 3      380361       5715452        Closed      currency 1         -993
# 4      380361       5715453        Closed      currency 1        -1146
# 5      380361       5715454        Closed      currency 1        -1622
# 6      380361       5715455        Closed      currency 1        -2631
# 7      380361       5715456        Closed      currency 1        -1449
# 8      380361       5715457        Active      currency 1         -222
# 9      380361       5715458        Closed      currency 1         -749
#
#    CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 0                   0              31069.0                NaN
# ...

# %%
df_aggregate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 774354 entries, 0 to 774353
# Data columns (total 18 columns):
# SK_ID_CURR                774354 non-null int64
# SK_ID_BUREAU              774354 non-null int64
# CREDIT_ACTIVE             774354 non-null object
# CREDIT_CURRENCY           774354 non-null object
# DAYS_CREDIT               774354 non-null int64
# CREDIT_DAY_OVERDUE        774354 non-null int64
# DAYS_CREDIT_ENDDATE       723869 non-null float64
# DAYS_ENDDATE_FACT         490889 non-null float64
# AMT_CREDIT_MAX_OVERDUE    234704 non-null float64
# CNT_CREDIT_PROLONG        774354 non-null int64
# AMT_CREDIT_SUM            774349 non-null float64
# AMT_CREDIT_SUM_DEBT       662000 non-null float64
# AMT_CREDIT_SUM_LIMIT      477791 non-null float64
# AMT_CREDIT_SUM_OVERDUE    774354 non-null float64
# CREDIT_TYPE               774354 non-null object
# DAYS_CREDIT_UPDATE        774354 non-null int64
# AMT_ANNUITY               489136 non-null float64
# ...

# %%
df_aggregate.iloc[6,17]
# Out:
# 'X'

# %%
df_groupby_aggregate = df_aggregate.groupby('SK_ID_CURR')['STATUS'].max()

# %%
df[df_aggregate['SK_ID_CURR']]

# %%
df_aggregate[df_aggregate['SK_ID_CURR']==100013]
# Out:
#         SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 125580      100013       5922083        Closed      currency 1        -2005
# 614937      100013       5922077        Closed      currency 1        -1210
# 614938      100013       5922081        Closed      currency 1        -2070
# 614939      100013       5922082        Closed      currency 1        -1665
#
#         CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 125580                   0               -909.0            -1334.0
# 614937                   0              -1089.0            -1118.0
# 614938                   0              -1707.0            -1218.0
# 614939                   0               -567.0             -549.0
#
#         AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 125580                 19305.0                   0       688500.00
# 614937                     NaN                   0        26490.06
# ...

# %%
df_groupby_aggregate
# Out:
# SK_ID_CURR
# 100001    X
# 100002    X
# 100005    X
# 100010    C
# 100013    X
# 100019    X
# 100028    X
# 100032    X
# 100033    X
# 100037    C
# 100042    X
# 100043    X
# 100048    0
# 100050    X
# 100054    C
# 100057    X
# 100059    X
# 100060    X
# 100061    C
# 100062    X
# 100063    X
# 100064    X
# 100065    X
# 100066    X
# 100067    X
# 100069    X
# 100072    X
# 100074    C
# 100076    1
# 100078    C
#          ..
# 456192    X
# 456193    X
# 456194    X
# 456201    X
# 456202    X
# 456208    C
# 456209    X
# 456213    X
# 456215    X
# 456217    X
# 456218    X
# 456219    X
# 456221    X
# 456223    X
# 456224    X
# 456225    X
# 456226    X
# 456230    X
# 456231    X
# 456233    0
# 456234    X
# 456235    C
# 456238    X
# 456242    0
# 456244    X
# 456247    X
# 456250    X
# 456253    X
# 456254    C
# 456255    X
# Name: STATUS, Length: 134542, dtype: object

# %%
df_bureau[df_bureau['SK_ID_CURR']==100003]
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 1024666      100003       5885877        Closed      currency 1        -2586
# 1024667      100003       5885878        Closed      currency 1        -1636
# 1024668      100003       5885879        Closed      currency 1         -775
# 1024669      100003       5885880        Active      currency 1         -606
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 1024666                   0              -2434.0            -2131.0
# 1024667                   0               -540.0             -540.0
# 1024668                   0               -420.0             -621.0
# 1024669                   0               1216.0                NaN
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 1024666                     0.0                   0         22248.0
# 1024667                     0.0                   0        112500.0
# ...

# %%
df_bureau_bal_max[df_bureau_bal_max['SK_ID_BUREAU']==5885880]
# Out:
# Empty DataFrame
# Columns: [SK_ID_BUREAU, STATUS]
# Index: []
